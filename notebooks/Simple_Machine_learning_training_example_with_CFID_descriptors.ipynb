# %% [markdown]
# <a href="https://colab.research.google.com/github/PMUSKET2/jarvis_leaderboard/blob/main/notebooks/Simple_Machine_learning_training_example_with_CFID_descriptors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table of contents
#
# 1. Loading CFID-3D dataset from figshare
# 2. Making pandas dataframe
# 3. Properties available, keys
# 4. Preparing training and target data
# 5. Simple regression traiing on 500 samples for formation energies
# 6. Visualizing training results

# %%
# !pip install jarvis-tools
# Out:
# Collecting jarvis-tools
#   Downloading jarvis_tools-2026.4.2-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.20.1 in /usr/local/lib/python3.12/dist-packages (from jarvis-tools) (2.0.2)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from jarvis-tools) (1.16.3)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from jarvis-tools) (3.10.0)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.12/dist-packages (from jarvis-tools) (1.5.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from jarvis-tools) (2.32.4)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jarvis-tools) (0.12.1)
# Collecting xmltodict>=0.11.0 (from jarvis-tools)
#   Downloading xmltodict-1.0.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.12/dist-packages (from jarvis-tools) (4.67.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from jarvis-tools) (1.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->jarvis-tools) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->jarvis-tools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->jarvis-tools) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->jarvis-tools) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->jarvis-tools) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->jarvis-tools) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->jarvis-tools) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->jarvis-tools) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->jarvis-tools) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->jarvis-tools) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->jarvis-tools) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->jarvis-tools) (2026.2.25)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->jarvis-tools) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->jarvis-tools) (1.17.0)
# Downloading jarvis_tools-2026.4.2-py2.py3-none-any.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 30.2 MB/s eta 0:00:00
# Downloading xmltodict-1.0.4-py3-none-any.whl (13 kB)
# Installing collected packages: xmltodict, jarvis-tools
# Successfully installed jarvis-tools-2026.4.2 xmltodict-1.0.4

# %%
# !pip install jarvis-tools, and restart runtime in the notebook if you haven't installed it yet
from jarvis.db.figshare import data
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

cfid_3d = data('cfid_3d')
# Out:
# Obtaining 3D dataset 55k ...
# Reference:https://www.nature.com/articles/s41524-020-00440-1
# Other versions:https://doi.org/10.6084/m9.figshare.6815699
# 100%|██████████| 446M/446M [00:15<00:00, 28.0MiB/s]
# Loading the zipfile...
# Loading completed.

# %%
len(cfid_3d)
# Out:
# 55723

# %%
typical_data_ranges = {'formation_energy_peratom': [-5, 5], 'optb88vdw_bandgap': [0, 10], 'mbj_bandgap': [0, 10], 'bulk_modulus_kv': [0, 250], 'shear_modulus_gv': [0, 250], 'epsx': [0, 60], 'epsy': [0, 60], 'epsz': [0, 60], 'mepsx': [0, 60], 'mepsy': [0, 60], 'mepsz': [0, 60], 'n-Seebeck': [-600, 10], 'n-powerfact': [0, 5000], 'p-Seebeck': [-10, 600], 'p-powerfact': [0, 5000], 'slme': [0, 40], 'spillage': [0, 4], 'encut': [0, 2000], 'kpoint_length_unit': [0, 200], 'dfpt_piezo_max_dielectric': [0, 100], 'dfpt_piezo_max_dij': [0, 3000], 'dfpt_piezo_max_eij': [0, 10], 'ehull': [0, 1], 'electron_avg_effective_masses_300K': [0, 3], 'hole_avg_effective_masses_300K': [0, 3], 'exfoliation_energy': [0, 1000], 'magmom_oszicar': [0, 10], 'max_ir_mode': [0, 4000], 'total_energy_per_atom': [-10, 3]}

# %%
typical_data_ranges
# Out:
# {'formation_energy_peratom': [-5, 5],
#  'optb88vdw_bandgap': [0, 10],
#  'mbj_bandgap': [0, 10],
#  'bulk_modulus_kv': [0, 250],
#  'shear_modulus_gv': [0, 250],
#  'epsx': [0, 60],
#  'epsy': [0, 60],
#  'epsz': [0, 60],
#  'mepsx': [0, 60],
#  'mepsy': [0, 60],
#  'mepsz': [0, 60],
#  'n-Seebeck': [-600, 10],
#  'n-powerfact': [0, 5000],
#  'p-Seebeck': [-10, 600],
#  'p-powerfact': [0, 5000],
#  'slme': [0, 40],
#  'spillage': [0, 4],
#  'encut': [0, 2000],
#  'kpoint_length_unit': [0, 200],
#  'dfpt_piezo_max_dielectric': [0, 100],
#  'dfpt_piezo_max_dij': [0, 3000],
#  'dfpt_piezo_max_eij': [0, 10],
#  'ehull': [0, 1],
#  'electron_avg_effective_masses_300K': [0, 3],
#  'hole_avg_effective_masses_300K': [0, 3],
#  'exfoliation_energy': [0, 1000],
#  'magmom_oszicar': [0, 10],
#  'max_ir_mode': [0, 4000],
#  'total_energy_per_atom': [-10, 3]}

# %%
df=pd.DataFrame(cfid_3d)

# %%
df.columns
# Out:
# Index(['jid', 'spg_number', 'spg_symbol', 'formula',
#        'formation_energy_peratom', 'func', 'optb88vdw_bandgap', 'atoms',
#        'slme', 'magmom_oszicar', 'spillage', 'elastic_tensor',
#        'effective_masses_300K', 'kpoint_length_unit', 'maxdiff_mesh',
#        'maxdiff_bz', 'encut', 'optb88vdw_total_energy', 'epsx', 'epsy', 'epsz',
#        'mepsx', 'mepsy', 'mepsz', 'modes', 'magmom_outcar', 'max_efg',
#        'avg_elec_mass', 'avg_hole_mass', 'icsd', 'dfpt_piezo_max_eij',
#        'dfpt_piezo_max_dij', 'dfpt_piezo_max_dielectric',
#        'dfpt_piezo_max_dielectric_electronic',
#        'dfpt_piezo_max_dielectric_ionic', 'max_ir_mode', 'min_ir_mode',
#        'n-Seebeck', 'p-Seebeck', 'n-powerfact', 'p-powerfact', 'ncond',
#        'pcond', 'nkappa', 'pkappa', 'ehull', 'dimensionality', 'efg',
#        'xml_data_link', 'typ', 'exfoliation_energy', 'spg', 'crys', 'density',
#        'poisson', 'raw_files', 'nat', 'bulk_modulus_kv', 'shear_modulus_gv',
#        'mbj_bandgap', 'hse_gap', 'reference', 'search', 'desc'],
#       dtype='object')

# %%
def get_ml_data(dataframe='', ml_property='formation_energy_peratom'):
    x = []
    y = []
    jid = []
    df2 = dataframe[['desc','jid',ml_property]].replace('na',np.nan).dropna()
    for ii,i in df2.iterrows():
        if len(i['desc']) ==1557 and float(i[ml_property])!=float('inf') and i[ml_property]!='na' \
            and float(i[ml_property])<typical_data_ranges[ml_property][1] \
            and float(i[ml_property])>typical_data_ranges[ml_property][0] :
            x.append(i['desc'])
            y.append(i[ml_property])
            jid.append(i['jid'])
    return np.array(x,dtype='float'),np.array(y,dtype='float'),jid

# %%
ml_property= 'formation_energy_peratom' #'bulk_modulus_kv'
x, y, jids = get_ml_data(dataframe=df, ml_property='formation_energy_peratom')

# %%
# 90 %-10 % train-test split
X_train, X_test, y_train, y_test,jid_train,jid_test = train_test_split(x, y,jids, random_state=1, test_size=0.1)
print (len(X_train), len(X_test))
# Out:
# 50150 5573

# %%
#Let's take 500 samples only for a quick training
# For more accurate models, higher number of points and hyper-parameter optimization etc. is needed
X1=X_train[0:500]
Y1=y_train[0:500]
X2=X_test[0:500]
Y2=y_test[0:500]
print (X1.shape)
# Out:
# (500, 1557)

# %%
#Typical hyperparameter optimized parameters in LightGBM:
#"n_estimators": 1170,
#"learning_rate": 0.15375236057119931,
#"num_leaves": 273,

# %%
# GB regressor with default parameters
model = GradientBoostingRegressor()
model.fit(X1,Y1)
# Out:
# GradientBoostingRegressor()

# %%
# predict on 10% held set which was not used during training
pred=model.predict(X2)

# %%
def regr_scores(pred, test):

    """
   Generic regresion scores
   Args:
       pred: predicted values
       test: held data for testing
   Returns:
        info: with metrics
   """

    rmse = np.sqrt(mean_squared_error(test, pred))
    r2 = r2_score(test, pred)
    mae = mean_absolute_error(test, pred)
    info = {}
    info["mae"] = mae
    info["rmse"] = rmse
    info["r2"] = r2
    info["test"] = test
    info["pred"] = pred
    return info

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
reg_sc=regr_scores(Y2,pred)
plt.plot(reg_sc['test'],reg_sc['pred'],'.')
plt.plot(reg_sc['test'],reg_sc['test'])
plt.xlabel('DFT-Formation energy (eV/atom)')
plt.ylabel('ML-Formation energy (eV/atom)')
# Out:
# Text(0, 0.5, 'ML-Formation energy (eV/atom)')

# %%
reg_sc
# Out:
# {'mae': 0.37298325317033887,
#  'rmse': np.float64(0.5475466706614437),
#  'r2': 0.6799014051160028,
#  'test': array([-7.86728575e-01, -4.00882978e-01, -7.72178134e-02,  2.39881477e-01,
#         -8.91561726e-02,  3.87007289e-02, -3.48572840e-01, -2.42081901e+00,
#         -1.83442995e+00,  4.07629563e-01, -2.23408630e+00,  5.20739230e-02,
#         -2.16370789e+00,  3.22915817e-01, -2.49499321e-01, -3.53480688e-01,
#         -2.78310359e-01, -4.03741412e-01,  1.64870034e-02, -4.50413726e-01,
#         -8.06756471e-01, -2.50871246e+00, -2.06234939e+00, -7.73724783e-01,
#         -5.32976250e-01, -7.67295232e-01, -2.80514088e+00, -5.17765500e-01,
#         -1.38141703e+00,  5.15400947e-01, -3.07334128e-01,  4.35580471e-01,
#         -2.34879467e+00, -1.18549350e+00, -2.50294350e+00, -5.25529596e-02,
#         -1.65156409e+00, -3.57545945e-01, -5.43154324e-01,  3.03026955e-01,
#         -9.13273362e-01, -1.46607815e+00, -1.87986164e-01, -2.48163657e+00,
#         -4.22415992e-01, -2.72544712e+00, -5.80661430e-01, -2.16578280e+00,
#         -1.04582207e+00,  1.69707615e-01, -5.57259461e-01,  2.65240902e-01,
#         -9.01709533e-02, -4.96470672e-01, -2.58263810e+00, -2.29548168e+00,
#          8.93005131e-02, -3.36331829e-01, -6.25791156e-01, -1.10748471e+00,
#         -2.51784591e-01, -2.55739105e+00, -2.35162859e+00,  7.58427601e-01,
#         -2.10101670e+00,  1.08511498e+00, -5.71092393e-01,  1.16406747e-01,
#         -5.33308411e-01, -1.19181321e+00,  3.19389439e-01, -4.09555237e-02,
#         -2.45233204e+00, -1.07692810e+00, -4.42141265e-01,  7.77114075e-01,
#         -3.86022610e-01, -1.89774379e+00,  4.66950559e-01, -1.12149903e+00,
#         -3.13031511e-01, -8.02241366e-01, -1.76619634e-01, -2.59552271e-01,
#         -3.20389684e-01, -2.03360318e+00,  1.06659857e-01, -1.32344718e-01,
#          1.42678266e-01, -7.14903193e-01, -3.14115684e-01, -7.05143582e-01,
#          1.27240033e-01, -7.82502181e-01,  8.70716433e-01, -2.42324201e-01,
#          3.97162487e-01, -3.13946535e-01, -6.62808751e-02, -2.80473788e-01,
#         -6.35340e-01, -5.67130e-01,  2.21310e-01, -2.25330e-01,
#         -2.23800e+00,  7.32580e-01, -2.85792e+00, -4.23050e-01,
#         -4.13110e-01,  7.54190e-01, -8.41450e-01, -3.68300e-01,
#         -4.40570e-01, -1.27160e+00, -1.97170e+00,  1.19369e+00,
#         -2.88909e+00, -3.53040e-01, -2.58870e-01, -3.41790e-01,
#         -6.74130e-01, -3.97747e+00, -4.49030e-01, -7.25980e-01,
#         -4.86270e-01, -3.92800e-02,  2.36250e-01,  6.11500e-02,
#         -3.74040e-01, -1.95362e+00, -3.06290e+00, -3.86950e-01,
#         -2.61741e+00,  1.05920e-01, -2.40040e-01, -4.51420e-01,
#         -1.45930e-01,  2.57170e-01,  2.08400e-02, -4.01130e-01,
#         -1.44073e+00, -3.89700e-02, -3.30547e+00, -1.34085e+00,
#          3.11030e-01, -2.15326e+00, -3.71290e-01, -5.67150e-01,
#         -7.20240e-01, -3.60420e-01, -1.73084e+00, -1.66288e+00,
#         -1.26410e+00, -1.65271e+00, -7.00970e-01, -1.20318e+00,
#         -7.28990e-01, -7.09970e-01, -2.91940e-01, -5.60720e-01,
#         -3.07920e+00, -3.71599e+00, -3.71469e+00, -1.79261e+00,
#         -1.41504e+00, -2.63830e-01,  2.15350e-01,  4.26900e-01,
#         -1.70542e+00, -1.61750e+00, -2.38316e+00, -2.27680e+00,
#         -4.22070e-01, -3.83640e-01,  2.62570e-01, -3.01400e-01,
#         -5.93300e-01, -2.30090e-01, -3.92350e-01, -1.95029e+00,
#          2.64180e-01, -2.74365e+00, -2.19250e-01, -2.06000e-01,
#         -3.10300e-01, -1.19434e+00, -5.65300e-02, -3.14874e+00,
#         -4.47190e-01, -1.66912e+00, -2.92069e+00, -1.60629e+00,
#          5.80730e-01, -1.41200e-02, -2.27980e-01, -9.79470e-01,
#         -6.03500e-02, -1.58144e+00, -1.72321e+00, -2.26988e+00,
#         -5.28400e-02,  1.01493e+00, -2.68781e+00, -2.05308e+00,
#         -2.15280e-01,  1.84630e-01, -1.34558e+00, -1.39626e+00,
#         -2.06625e+00,  1.45887e+00, -3.60091e+00, -5.50570e-01,
#          2.19283e+00, -1.30900e-01, -2.29010e+00, -8.83460e-01,
#         -1.48665e+00, -1.83170e-01, -3.81663e+00, -4.16910e-01,
#         -2.46591e+00, -9.59310e-01, -2.72260e-01, -4.96970e-01,
#         -2.80329e+00, -3.52156e+00,  2.56820e-01,  1.46560e-01])}

# %%
# ============================================================
# ELEMENT-FRACTION DESCRIPTOR EXAMPLE
# ============================================================
# Element fractions represent each material as a 103-dim vector
# where entry i = the fraction of element i in the composition.
# This is a much simpler featurization than the full 1557-dim CFID.
# ============================================================

from jarvis.core.composition import Composition

# --- Step 1: Build a jid -> formula lookup from dft_3d_2021 ---
# (same vintage as cfid_3d; shares the same jids)
dft_3d = data('dft_3d_2021')
jid_to_formula = {entry['jid']: entry['formula'] for entry in dft_3d}

# --- Step 2: Build element-fraction feature matrix ---
def get_ef_ml_data(dataframe='', ml_property='formation_energy_peratom'):
    x_ef = []
    y_ef = []
    jids_ef = []
    df2 = dataframe[['jid', ml_property]].replace('na', np.nan).dropna()
    for ii, i in df2.iterrows():
        jid = i['jid']
        if jid not in jid_to_formula:
            continue
        formula = jid_to_formula[jid]
        try:
            feat = Composition.from_string(formula).atomic_fraction_array  # 103-dim
        except Exception:
            continue
        val = i[ml_property]
        if (val != float('inf') and val != 'na'
                and float(val) < typical_data_ranges[ml_property][1]
                and float(val) > typical_data_ranges[ml_property][0]):
            x_ef.append(feat)
            y_ef.append(val)
            jids_ef.append(jid)
    return np.array(x_ef, dtype='float'), np.array(y_ef, dtype='float'), jids_ef

x_ef, y_ef, jids_ef = get_ef_ml_data(dataframe=df, ml_property='formation_energy_peratom')
print('Element-fraction feature shape:', x_ef.shape)   # expect (N, 103)

# --- Step 3: Train/test split (same 90/10 split) ---
X_train_ef, X_test_ef, y_train_ef, y_test_ef, jid_train_ef, jid_test_ef = \
    train_test_split(x_ef, y_ef, jids_ef, random_state=1, test_size=0.1)

# --- Step 4: Subset to 500 samples for quick training ---
X1_ef = X_train_ef[:500]
Y1_ef = y_train_ef[:500]
X2_ef = X_test_ef[:500]
Y2_ef = y_test_ef[:500]
print('Training shape:', X1_ef.shape)  # expect (500, 103)

# --- Step 5: Train GradientBoostingRegressor (same defaults) ---
model_ef = GradientBoostingRegressor()
model_ef.fit(X1_ef, Y1_ef)

# --- Step 6: Predict on held-out test set ---
pred_ef = model_ef.predict(X2_ef)

# --- Step 7: Evaluate and plot ---
reg_sc_ef = regr_scores(Y2_ef, pred_ef)
print('Element-fraction MAE  :', round(reg_sc_ef['mae'], 4))
print('Element-fraction RMSE :', round(reg_sc_ef['rmse'], 4))
print('Element-fraction R²   :', round(reg_sc_ef['r2'], 4))

plt.figure()
plt.plot(reg_sc_ef['test'], reg_sc_ef['pred'], '.')
plt.plot(reg_sc_ef['test'], reg_sc_ef['test'])
plt.xlabel('DFT-Formation energy (eV/atom)')
plt.ylabel('ML-Formation energy (eV/atom)')
plt.title('Element-Fraction Descriptors')
plt.show()
# Out:
# Obtaining 3D dataset 55k ...
# Reference:https://www.nature.com/articles/s41524-020-00440-1
# 100%|██████████| 31.9M/31.9M [00:01<00:00, 16.5MiB/s]
# Loading the zipfile...
# Loading completed.
# Element-fraction feature shape: (55723, 103)
# Training shape: (500, 103)
# Element-fraction MAE  : 0.4571
# Element-fraction RMSE : 0.6518
# Element-fraction R²   : 0.4322

# %%
import pandas as pd

# Create a dataframe with the test results
results_df = pd.DataFrame({
    'jid': jids_ef[:500],
    'dft_formation_energy': Y2_ef,
    'ml_prediction': pred_ef,
    'absolute_error': abs(Y2_ef - pred_ef)
})

# Add summary metrics as a separate sheet
metrics_df = pd.DataFrame({
    'metric': ['MAE', 'RMSE', 'R2'],
    'value': [reg_sc_ef['mae'], reg_sc_ef['rmse'], reg_sc_ef['r2']]
})

# Save to Excel with two sheets
with pd.ExcelWriter('element_fraction_results.xlsx', engine='openpyxl') as writer:
    results_df.to_excel(writer, sheet_name='Predictions', index=False)
    metrics_df.to_excel(writer, sheet_name='Metrics', index=False)

print("Saved: element_fraction_results.xlsx")
# Out:
# Saved: element_fraction_results.xlsx
